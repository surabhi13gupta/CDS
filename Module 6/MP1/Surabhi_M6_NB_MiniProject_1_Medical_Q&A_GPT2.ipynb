# %% [markdown]
# <a href="https://colab.research.google.com/github/surabhi13gupta/CDS/blob/main/Module%206/MP1/Surabhi_M6_NB_MiniProject_1_Medical_Q%26A_GPT2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Advanced Certification Program in Computational Data Science
# ## A programme by IISc and TalentSprint
# ### Mini-Project: Medical Q&A using GPT2

# %% [markdown]
# ## Learning Objectives
#
# At the end of the experiment, you will be able to:
#
# * perform data preprocessing, EDA and feature extraction on the Medical Q&A dataset
# * load a pre-trained tokenizer
# * finetune a GPT-2 language model for medical question-answering

# %% [markdown]
# ## Dataset Description
#
# The dataset used in this project is the *Medical Question Answering Dataset* ([MedQuAD](https://github.com/abachaa/MedQuAD/tree/master)). It includes medical question-answer pairs along with additional information, such as the question type, the question *focus*, its UMLS(Unified Medical Language System) details like - Concept Unique Identifier(*CUI*) and Semantic *Type* and *Group*.
#
# To know more about this data's collection, and construction method, refer to this [paper](https://bmcbioinformatics.biomedcentral.com/articles/10.1186/s12859-019-3119-4).
#
# The data is extracted and is in CSV format with below features:
#
# - **Focus**: the question focus
# - **CUI**: concept unique identifier
# - **SemanticType**
# - **SemanticGroup**
# - **Question**
# - **Answer**

# %% [markdown]
# ## Part-A: Grading = 10 Points

# %% [markdown]
# ## Information

# %% [markdown]
# Healthcare professionals often have to refer to medical literature and documents while seeking answers to medical queries. Medical databases or search engines are powerful resources of upto date medical knowledge. However, the existing documentation is large and makes it difficult for professionals to retrieve answers quickly in a clinical setting. The problem with search engines and informative retrieval engines is that these systems return a list of documents rather than answers. Instead, healthcare professionals can use question answering systems to retrieve short sentences or paragraphs in response to medical queries. Such systems have the biggest advantage of generating answers and providing hints in a few seconds.

# %% [markdown]
# ### Problem Statement

# %% [markdown]
# Fine-tune gpt2 model on medical-question-answering-dataset for performing response generation for medical queries.
#
# Please refer to ***M6 Assignment-1 Fine-tune GPT2*** to get familiar with how to load pre-trained gpt2 tokenizer and model.

# %% [markdown]
# ### Import required packages

# %%
# !pip -q install -U accelerate
# !pip -q install -U transformers
# !pip -q install torch
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 35.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 32.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 98.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.5/10.5 MB 130.2 MB/s eta 0:00:00

# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import torch
from transformers import GPT2Tokenizer, GPT2LMHeadModel, TextDataset, DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments

import warnings
warnings.filterwarnings('ignore')

# %%
#@title Download the dataset
# !wget -q https://cdn.iisc.talentsprint.com/AIandMLOps/MiniProjects/Datasets/MedQuAD.csv
# !ls | grep ".csv"
# Out:
# MedQuAD.csv

# %% [markdown]
# **Exercise 1: Read the MedQuAD.csv dataset**
#
# **Hint:** pd.read_csv()

# %%
df = pd.read_csv("MedQuAD.csv")
df.shape
# Out:
# (16412, 6)

# %%
df.head()
# Out:
#                                 Focus       CUI SemanticType SemanticGroup  \
# 0  Adult Acute Lymphoblastic Leukemia  C0751606         T191     Disorders
# 1  Adult Acute Lymphoblastic Leukemia  C0751606         T191     Disorders
# 2  Adult Acute Lymphoblastic Leukemia  C0751606         T191     Disorders
# 3  Adult Acute Lymphoblastic Leukemia  C0751606         T191     Disorders
# 4  Adult Acute Lymphoblastic Leukemia  C0751606         T191     Disorders
#
#                                             Question  \
# 0  What is (are) Adult Acute Lymphoblastic Leukem...
# 1  What are the symptoms of Adult Acute Lymphobla...
# 2  How to diagnose Adult Acute Lymphoblastic Leuk...
# 3  What is the outlook for Adult Acute Lymphoblas...
# 4  Who is at risk for Adult Acute Lymphoblastic L...
#
#                                               Answer
# 0  Key Points - Adult acute lymphoblastic leukemi...
# 1  Signs and symptoms of adult ALL include fever,...
# 2  Tests that examine the blood and bone marrow a...
# 3  Certain factors affect prognosis (chance of re...
# 4  Previous chemotherapy and exposure to radiatio...

# %% [markdown]
# ### Pre-processing and EDA

# %% [markdown]
# **Exercise 2: Perform below operations on the dataset [0.5 Mark]**
#
# - Handle missing values
# - Remove duplicates from data considering `Question` and `Answer` columns

# %% [markdown]
# - **Handle missing values**

# %%
# YOUR CODE HERE
print("Check if any missing values")
print("=======================================================================")
print(df.isna().sum())
# Out:
# Check if any missing values
# =======================================================================
# Focus             14
# CUI              565
# SemanticType     597
# SemanticGroup    565
# Question           0
# Answer             5
# dtype: int64

# %%
print("List down rows where Focus is null")
print("======================================================================")
df[df.Focus.isna()]
# Out:
# List down rows where Focus is null
# ======================================================================
#       Focus  CUI SemanticType SemanticGroup  \
# 16234   NaN  NaN          NaN           NaN
# 16235   NaN  NaN          NaN           NaN
# 16236   NaN  NaN          NaN           NaN
# 16237   NaN  NaN          NaN           NaN
# 16386   NaN  NaN          NaN           NaN
# 16387   NaN  NaN          NaN           NaN
# 16388   NaN  NaN          NaN           NaN
# 16389   NaN  NaN          NaN           NaN
# 16390   NaN  NaN          NaN           NaN
# 16391   NaN  NaN          NaN           NaN
# 16392   NaN  NaN          NaN           NaN
# 16393   NaN  NaN          NaN           NaN
# 16394   NaN  NaN          NaN           NaN
# 16395   NaN  NaN          NaN           NaN
#
#                                                 Question  \
# 16234                       how vaccines prevent disease
# 16235                             Who is at risk for ? ?
# 16236                                  How to prevent  ?
# 16237              what diseases are vaccine preventable
# 16386                                   What is (are)  ?
# 16387                     what is staphylococcus aureus?
# 16388  how can the spread of visa and vrsa be prevented?
# 16389        what is cdc doing to address visa and vrsa?
# 16390                                   What is (are)  ?
# 16391          what is vancomycin-resistant enterococci?
# 16392  what types of infections does vancomycin-resis...
# 16393  are certain people at risk of getting vancomyc...
# 16394  what is the treatment for vancomycin-resistant...
# 16395  how can patients prevent the spread of vancomy...
#
#                                                   Answer
# 16234  Why Are Childhood Vaccines So Important? It is...
# 16235  Measles: Make Sure Your Child Is Protected wit...
# 16236  Vaccines and Preventable Diseases On this Page...
# 16237  List of Vaccine-Preventable Diseases The follo...
# 16386  On this Page General Information about VISA/VR...
# 16387  On this Page General Information about VISA/VR...
# 16388  On this Page General Information about VISA/VR...
# 16389  On this Page General Information about VISA/VR...
# 16390  On this Page General Information What is vanco...
# 16391  On this Page General Information What is vanco...
# 16392  On this Page General Information What is vanco...
# 16393  On this Page General Information What is vanco...
# 16394  On this Page General Information What is vanco...
# 16395  On this Page General Information What is vanco...

# %%
print("List down rows where Answer is null")
print("======================================================================")
df[df.Answer.isna()]
# Out:
# List down rows where Answer is null
# ======================================================================
#                                                  Focus       CUI SemanticType  \
# 2263  Emery-Dreifuss muscular dystrophy, dominant type  C0410189         T047
# 2264       Emery-Dreifuss muscular dystrophy, X-linked  C0410189         T047
# 2400                           Familial HDL deficiency  C2931838         T047
# 2876                                    HELLP syndrome  C0162739         T047
# 6021             X-linked lymphoproliferative syndrome  C0549463         T191
#
#      SemanticGroup                                           Question Answer
# 2263     Disorders  What is (are) Emery-Dreifuss muscular dystroph...    NaN
# 2264     Disorders  What is (are) Emery-Dreifuss muscular dystroph...    NaN
# 2400     Disorders            What is (are) Familial HDL deficiency ?    NaN
# 2876     Disorders                     What is (are) HELLP syndrome ?    NaN
# 6021     Disorders  What is (are) X-linked lymphoproliferative syn...    NaN

# %%
orig = df.shape[0]
print("Number of rows before dropping null values present in Focus and Answer columns : ", orig)
print("======================================================================")
df = df.dropna(subset=['Focus', 'Answer'])
print("Number of rows after dropping null values present in Focus and Answer columns : ", df.shape[0])
print("======================================================================")
print("Rows removed: ", df.shape[0]-orig)
# Out:
# Number of rows before dropping null values present in Focus and Answer columns :  16412
# ======================================================================
# Number of rows after dropping null values present in Focus and Answer columns :  16393
# ======================================================================
# Rows removed:  -19

# %%
print("Check if any missing values")
print("=======================================================================")
print(df.isna().sum())
# Out:
# Check if any missing values
# =======================================================================
# Focus              0
# CUI              551
# SemanticType     583
# SemanticGroup    551
# Question           0
# Answer             0
# dtype: int64

# %%
print("List down rows where SemanticGroup is null")
print("======================================================================")
df[df.SemanticGroup.isna()]["Focus"].drop_duplicates()
# Out:
# List down rows where SemanticGroup is null
# ======================================================================
# 11553                                                  A1C
# 11559                                          Acupuncture
# 11565                                             Adoption
# 11568                                   Advance Directives
# 11569                              African American Health
#                                ...
# 16385                                        Typhoid Fever
# 16396    Parasites - Trichuriasis (also known as Whipwo...
# 16401                             Yellow Fever Vaccination
# 16402                                             Yersinia
# 16407                        Parasites - Zoonotic Hookworm
# Name: Focus, Length: 351, dtype: object

# %%
df[df.Focus=="Parasites - Zoonotic Hookworm"]
# Out:
#                                Focus  CUI SemanticType SemanticGroup  \
# 16407  Parasites - Zoonotic Hookworm  NaN          NaN           NaN
# 16408  Parasites - Zoonotic Hookworm  NaN          NaN           NaN
# 16409  Parasites - Zoonotic Hookworm  NaN          NaN           NaN
# 16410  Parasites - Zoonotic Hookworm  NaN          NaN           NaN
# 16411  Parasites - Zoonotic Hookworm  NaN          NaN           NaN
#
#                                                 Question  \
# 16407      What is (are) Parasites - Zoonotic Hookworm ?
# 16408  Who is at risk for Parasites - Zoonotic Hookwo...
# 16409    How to diagnose Parasites - Zoonotic Hookworm ?
# 16410  What are the treatments for Parasites - Zoonot...
# 16411     How to prevent Parasites - Zoonotic Hookworm ?
#
#                                                   Answer
# 16407  There are many different species of hookworms,...
# 16408  Dog and cat hookworms are found throughout the...
# 16409  Cutaneous larva migrans (CLM) is a clinical di...
# 16410  The zoonotic hookworm larvae that cause cutane...
# 16411  Wearing shoes and taking other protective meas...

# %%
df[df.Focus=="Yellow Fever Vaccination"]
# Out:
#                           Focus  CUI SemanticType SemanticGroup  \
# 16401  Yellow Fever Vaccination  NaN          NaN           NaN
#
#                                        Question  \
# 16401  What is (are) Yellow Fever Vaccination ?
#
#                                                   Answer
# 16401  If you continue to live or travel in yellow fe...

# %% [markdown]
# For any focus - SemanticGroup and CUI are missing for all rows and nothing can be filled from previous. Drop 551 rows

# %%
orig = df.shape[0]
print("Number of rows before dropping null values present in SemanticGroup and CUI columns : ", orig)
print("======================================================================")
df = df.dropna(subset=['SemanticGroup', 'CUI'])
print("Number of rows after dropping null values present in SemanticGroup and CUI columns : ", df.shape[0])
print("======================================================================")
print("Rows removed: ", orig-df.shape[0])
# Out:
# Number of rows before dropping null values present in SemanticGroup and CUI columns :  16393
# ======================================================================
# Number of rows after dropping null values present in SemanticGroup and CUI columns :  15842
# ======================================================================
# Rows removed:  551

# %%
print("Check if any missing values")
print("=======================================================================")
print(df.isna().sum())
# Out:
# Check if any missing values
# =======================================================================
# Focus             0
# CUI               0
# SemanticType     32
# SemanticGroup     0
# Question          0
# Answer            0
# dtype: int64

# %%
print("List down rows where SemanticType is null")
print("======================================================================")
df[df.SemanticType.isna()]
# Out:
# List down rows where SemanticType is null
# ======================================================================
#                                        Focus       CUI SemanticType  \
# 1124  Autosomal recessive hyper IgE syndrome  C0022398          NaN
# 1125  Autosomal recessive hyper IgE syndrome  C0022398          NaN
# 1154               Baraitser-Winter syndrome  C0796084          NaN
# 4660             Periventricular heterotopia  C3714789          NaN
# 4661             Periventricular heterotopia  C3714789          NaN
# 4662             Periventricular heterotopia  C3714789          NaN
# 4663             Periventricular heterotopia  C3714789          NaN
# 6568   autosomal dominant hyper-IgE syndrome  C0022398          NaN
# 6569   autosomal dominant hyper-IgE syndrome  C0022398          NaN
# 6570   autosomal dominant hyper-IgE syndrome  C0022398          NaN
# 6571   autosomal dominant hyper-IgE syndrome  C0022398          NaN
# 6572   autosomal dominant hyper-IgE syndrome  C0022398          NaN
# 6613  autosomal recessive hyper-IgE syndrome  C0022398          NaN
# 6614  autosomal recessive hyper-IgE syndrome  C0022398          NaN
# 6615  autosomal recessive hyper-IgE syndrome  C0022398          NaN
# 6616  autosomal recessive hyper-IgE syndrome  C0022398          NaN
# 6617  autosomal recessive hyper-IgE syndrome  C0022398          NaN
# 6648               Baraitser-Winter syndrome  C0796084          NaN
# 6649               Baraitser-Winter syndrome  C0796084          NaN
# 6650               Baraitser-Winter syndrome  C0796084          NaN
# 6651               Baraitser-Winter syndrome  C0796084          NaN
# 6652               Baraitser-Winter syndrome  C0796084          NaN
# 7233              congenital hyperinsulinism  C2931834          NaN
# 7234              congenital hyperinsulinism  C2931834          NaN
# 7235              congenital hyperinsulinism  C2931834          NaN
# 7236              congenital hyperinsulinism  C2931834          NaN
# 7237              congenital hyperinsulinism  C2931834          NaN
# 9973             periventricular heterotopia  C3714789          NaN
# 9974             periventricular heterotopia  C3714789          NaN
# 9975             periventricular heterotopia  C3714789          NaN
# 9976             periventricular heterotopia  C3714789          NaN
# 9977             periventricular heterotopia  C3714789          NaN
#
#      SemanticGroup                                           Question  \
# 1124     Disorders  What is (are) Autosomal recessive hyper IgE sy...
# 1125     Disorders  What are the symptoms of Autosomal recessive h...
# 1154     Disorders  What are the symptoms of Baraitser-Winter synd...
# 4660     Disorders        What is (are) Periventricular heterotopia ?
# 4661     Disorders  What are the symptoms of Periventricular heter...
# 4662     Disorders      How to diagnose Periventricular heterotopia ?
# 4663     Disorders  What are the treatments for Periventricular he...
# 6568     Disorders  What is (are) autosomal dominant hyper-IgE syn...
# 6569     Disorders  How many people are affected by autosomal domi...
# 6570     Disorders  What are the genetic changes related to autoso...
# 6571     Disorders  Is autosomal dominant hyper-IgE syndrome inher...
# 6572     Disorders  What are the treatments for autosomal dominant...
# 6613     Disorders  What is (are) autosomal recessive hyper-IgE sy...
# 6614     Disorders  How many people are affected by autosomal rece...
# 6615     Disorders  What are the genetic changes related to autoso...
# 6616     Disorders  Is autosomal recessive hyper-IgE syndrome inhe...
# 6617     Disorders  What are the treatments for autosomal recessiv...
# 6648     Disorders          What is (are) Baraitser-Winter syndrome ?
# 6649     Disorders  How many people are affected by Baraitser-Wint...
# 6650     Disorders  What are the genetic changes related to Barait...
# 6651     Disorders           Is Baraitser-Winter syndrome inherited ?
# 6652     Disorders  What are the treatments for Baraitser-Winter s...
# 7233     Disorders         What is (are) congenital hyperinsulinism ?
# 7234     Disorders  How many people are affected by congenital hyp...
# 7235     Disorders  What are the genetic changes related to congen...
# 7236     Disorders          Is congenital hyperinsulinism inherited ?
# 7237     Disorders  What are the treatments for congenital hyperin...
# 9973     Disorders        What is (are) periventricular heterotopia ?
# 9974     Disorders  How many people are affected by periventricula...
# 9975     Disorders  What are the genetic changes related to perive...
# 9976     Disorders         Is periventricular heterotopia inherited ?
# 9977     Disorders  What are the treatments for periventricular he...
#
#                                                  Answer
# 1124  Autosomal recessive hyper IgE syndrome (AR-HIE...
# 1125  What are the signs and symptoms of Autosomal r...
# 1154  What are the signs and symptoms of Baraitser-W...
# 4660  Periventricular heterotopia is a condition in ...
# 4661  What are the signs and symptoms of periventric...
# 4662  What are the recommended evaluations for patie...
# 4663  How might periventricular nodular heterotopia ...
# 6568  Autosomal dominant hyper-IgE syndrome (AD-HIES...
# 6569  This condition is rare, affecting fewer than 1...
# 6570  Mutations in the STAT3 gene cause most cases o...
# 6571  AD-HIES has an autosomal dominant pattern of i...
# 6572  These resources address the diagnosis or manag...
# 6613  Autosomal recessive hyper-IgE syndrome (AR-HIE...
# 6614  AR-HIES is a rare disorder whose prevalence is...
# 6615  AR-HIES is usually caused by mutations in the ...
# 6616  This condition is inherited in an autosomal re...
# 6617  These resources address the diagnosis or manag...
# 6648  Baraitser-Winter syndrome is a condition that ...
# 6649  Baraitser-Winter syndrome is a rare condition....
# 6650  Baraitser-Winter syndrome can result from muta...
# 6651  This condition is described as autosomal domin...
# 6652  These resources address the diagnosis or manag...
# 7233  Congenital hyperinsulinism is a condition that...
# 7234  Congenital hyperinsulinism affects approximate...
# 7235  Congenital hyperinsulinism is caused by mutati...
# 7236  Congenital hyperinsulinism can have different ...
# 7237  These resources address the diagnosis or manag...
# 9973  Periventricular heterotopia is a condition in ...
# 9974  Periventricular heterotopia is a rare conditio...
# 9975  Periventricular heterotopia is related to chro...
# 9976  Periventricular heterotopia can have different...
# 9977  These resources address the diagnosis or manag...

# %%
df[df.Focus=="Periventricular heterotopia"]
# Out:
#                             Focus       CUI SemanticType SemanticGroup  \
# 4660  Periventricular heterotopia  C3714789          NaN     Disorders
# 4661  Periventricular heterotopia  C3714789          NaN     Disorders
# 4662  Periventricular heterotopia  C3714789          NaN     Disorders
# 4663  Periventricular heterotopia  C3714789          NaN     Disorders
#
#                                                Question  \
# 4660        What is (are) Periventricular heterotopia ?
# 4661  What are the symptoms of Periventricular heter...
# 4662      How to diagnose Periventricular heterotopia ?
# 4663  What are the treatments for Periventricular he...
#
#                                                  Answer
# 4660  Periventricular heterotopia is a condition in ...
# 4661  What are the signs and symptoms of periventric...
# 4662  What are the recommended evaluations for patie...
# 4663  How might periventricular nodular heterotopia ...

# %%
df[df.Focus=="periventricular heterotopia"]
# Out:
#                             Focus       CUI SemanticType SemanticGroup  \
# 9973  periventricular heterotopia  C3714789          NaN     Disorders
# 9974  periventricular heterotopia  C3714789          NaN     Disorders
# 9975  periventricular heterotopia  C3714789          NaN     Disorders
# 9976  periventricular heterotopia  C3714789          NaN     Disorders
# 9977  periventricular heterotopia  C3714789          NaN     Disorders
#
#                                                Question  \
# 9973        What is (are) periventricular heterotopia ?
# 9974  How many people are affected by periventricula...
# 9975  What are the genetic changes related to perive...
# 9976         Is periventricular heterotopia inherited ?
# 9977  What are the treatments for periventricular he...
#
#                                                  Answer
# 9973  Periventricular heterotopia is a condition in ...
# 9974  Periventricular heterotopia is a rare conditio...
# 9975  Periventricular heterotopia is related to chro...
# 9976  Periventricular heterotopia can have different...
# 9977  These resources address the diagnosis or manag...

# %% [markdown]
# Can drp all 32 rows because nothing can be filled from previous

# %%
orig = df.shape[0]
print("Number of rows before dropping null values present in SemanticType columns : ", orig)
print("======================================================================")
df = df.dropna(subset=['SemanticType'])
print("Number of rows after dropping null values present in SemanticType columns : ", df.shape[0])
print("======================================================================")
print("Rows removed: ", orig-df.shape[0])
# Out:
# Number of rows before dropping null values present in SemanticType columns :  15842
# ======================================================================
# Number of rows after dropping null values present in SemanticType columns :  15810
# ======================================================================
# Rows removed:  32

# %%
print("Check if any missing values")
print("=======================================================================")
print(df.isna().sum())
# Out:
# Check if any missing values
# =======================================================================
# Focus            0
# CUI              0
# SemanticType     0
# SemanticGroup    0
# Question         0
# Answer           0
# dtype: int64

# %% [markdown]
# - **Remove duplicates from data considering `Question` and `Answer` columns**

# %%
# Check duplicates
# YOUR CODE HERE
print("Checking for duplicate rows:")
print("=======================================================================")
dup = df[df[["Question", "Answer"]].duplicated()]
print("Rows are exactly duplicate: ", dup.shape[0])
print("=======================================================================")
print("%age of rows having duplicate : ", (dup.shape[0]/df.shape[0]) *100 )
# Out:
# Checking for duplicate rows:
# =======================================================================
# Rows are exactly duplicate:  48
# =======================================================================
# %age of rows having duplicate :  0.3036053130929791

# %%
# Drop duplicates
# YOUR CODE HERE
print("Shape before dropping duplicate rows: ", df.shape, sep="\n")
print("=======================================================================")
print("Drop duplicate rows", sep="\n")
print("=======================================================================")
df = df.drop_duplicates()
df = df.reset_index()
df = df.drop(['index'], axis=1)
print("Shape after dropping duplicate rows: ", df.shape, sep="\n")
print("=======================================================================")
# Out:
# Shape before dropping duplicate rows:
# (15810, 6)
# =======================================================================
# Drop duplicate rows
# =======================================================================
# Shape after dropping duplicate rows:
# (15762, 6)
# =======================================================================

# %%
# Check duplicates
# YOUR CODE HERE
print("Checking for duplicate rows:")
print("=======================================================================")
dup = df[df[["Question", "Answer"]].duplicated()]
print("Rows are exactly duplicate: ", dup.shape[0])
print("=======================================================================")
print("%age of rows having duplicate : ", (dup.shape[0]/df.shape[0]) *100 )
# Out:
# Checking for duplicate rows:
# =======================================================================
# Rows are exactly duplicate:  0
# =======================================================================
# %age of rows having duplicate :  0.0

# %% [markdown]
# **Exercise 3: Display the category name, and the number of records belonging to top 100 categories of `Focus` column [1 Mark]**

# %%
# YOUR CODE HERE
print("Unique Categories i.e. Focus area")
print("====================================================================")
df["Focus"].value_counts().reset_index()
# Out:
# Unique Categories i.e. Focus area
# ====================================================================
#                                            Focus  count
# 0                                  Breast Cancer     53
# 1                                Prostate Cancer     43
# 2                                         Stroke     35
# 3                                    Skin Cancer     34
# 4                            Alzheimer's Disease     30
# ...                                          ...    ...
# 4765                   Growth hormone deficiency      1
# 4766  Ghosal hematodiaphyseal dysplasia syndrome      1
# 4767                     Giant platelet syndrome      1
# 4768                    Gingival fibromatosis, 1      1
# 4769                       Hairy palms and soles      1
#
# [4770 rows x 2 columns]

# %%
# Top 100 Focus categories names
# YOUR CODE HERE
print("Top 100 Focus categories")
print("====================================================================")
df["Focus"].value_counts().reset_index().head(100)
# Out:
# Top 100 Focus categories
# ====================================================================
#                                   Focus  count
# 0                         Breast Cancer     53
# 1                       Prostate Cancer     43
# 2                                Stroke     35
# 3                           Skin Cancer     34
# 4                   Alzheimer's Disease     30
# ..                                  ...    ...
# 95               Alzheimer's Caregiving     11
# 96                    Polycythemia Vera     11
# 97  Diabetes, Heart Disease, and Stroke     11
# 98         Pelizaeus-Merzbacher disease     10
# 99               Peutz-Jeghers syndrome     10
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Create Training and Validation set

# %% [markdown]
# **Exercise 4: Create training and validation set [2 Marks]**
#
# - Consider 4 samples per `Focus` category, for each top 100 categories, from the dataset (It will give 400 samples for training)
#
# - Consider 1 sample per `Focus` category (different from training set), for each top 100 categories, from the dataset (It will give 100 samples for validation)

# %%
top_100_categories = df["Focus"].value_counts().reset_index().head(100)['Focus'].to_list()

# %%
# YOUR CODE HERE
df_for_100_categories = df[df['Focus'].isin(top_100_categories)]
df_for_100_categories.shape
# Out:
# (1532, 6)

# %% [markdown]
# Train expectation: 400,6
#
#
# Validation set: 100,6

# %%
shuffled_dataset = df_for_100_categories.sample(frac=1, replace=False, random_state=42)
train_df = shuffled_dataset.groupby('Focus').head(4).reset_index(drop=True)
val_df = shuffled_dataset.groupby('Focus').tail(1).reset_index(drop=True)

# %%
print("Shape of training dataset: ", train_df.shape)
print("Shape of validation dataset: ", val_df.shape)
# Out:
# Shape of training dataset:  (400, 6)
# Shape of validation dataset:  (100, 6)

# %%
train_df.head()
# Out:
#                      Focus       CUI SemanticType SemanticGroup  \
# 0        Colorectal Cancer  C1527249         T191     Disorders
# 1         Pituitary Tumors  C0032019         T191     Disorders
# 2          Liddle syndrome  C0221043         T047     Disorders
# 3        Urinary Retention  C0080274         T033     Disorders
# 4  Medullary Sponge Kidney  C0022681         T019     Disorders
#
#                                             Question  \
# 0            Who is at risk for Colorectal Cancer? ?
# 1          What are the stages of Pituitary Tumors ?
# 2  How many people are affected by Liddle syndrome ?
# 3    What are the treatments for Urinary Retention ?
# 4            What is (are) Medullary Sponge Kidney ?
#
#                                               Answer
# 0  Researchers are working hard to understand and...
# 1  Key Points - Once a pituitary tumor has been d...
# 2  Liddle syndrome is a rare condition, although ...
# 3  A health care provider treats urinary retentio...
# 4  Medullary sponge kidney, also known as Cacchi-...

# %%
val_df.head()
# Out:
#                                                Focus       CUI SemanticType  \
# 0                      Langerhans cell histiocytosis  C0019621         T191
# 1                         Camurati-Engelmann disease  C0011989         T019
# 2  National Hormone and Pituitary Program (NHPP):...  C0032002         T047
# 3                                         Depression  C0349217         T048
# 4                                      Danon disease  C0878677         T047
#
#   SemanticGroup                                           Question  \
# 0     Disorders       Is Langerhans cell histiocytosis inherited ?
# 1     Disorders  What are the genetic changes related to Camura...
# 2     Disorders  What are the treatments for National Hormone a...
# 3     Disorders                         What is (are) Depression ?
# 4     Disorders                       Is Danon disease inherited ?
#
#                                               Answer
# 0  Is Langerhans cell histiocytosis inherited? Al...
# 1  Mutations in the TGFB1 gene cause Camurati-Eng...
# 2  Some parents did not tell their children about...
# 3  Depression is more than just feeling blue or s...
# 4  How is Danon disease inherited? Dannon disease...

# %% [markdown]
# ### Pre-process `Question` and `Answer` text
#
# **Exercise 5: Perform below tasks: [1.5 Marks]**
#
# - Combine `Question` and `Answer` for train and validation data as shown below:
#     - sequence = *'\<question\>' + question-text + '\<answer\>' + answer-text*
#
# - Join the combined text using '\n' into a single string for training and validation separately
#
# - Save the training and validation strings as separate text files

# %% [markdown]
# - **Combine Question and Answer for train and val data**

# %%
# YOUR CODE HERE
train_df['Question-Answer'] = train_df[['Question', 'Answer']].apply(lambda x: '<question>{}<answer>{}'.format(x[0], x[1]), axis=1)
val_df['Question-Answer'] = val_df[['Question', 'Answer']].apply(lambda x: '<question>{}<answer>{}'.format(x[0], x[1]), axis=1)

# %%
train_df.loc[0,"Question"], train_df.loc[0,"Answer"], train_df.loc[0,"Question-Answer"]
# Out:
# ('Who is at risk for Colorectal Cancer? ?',
#  'Researchers are working hard to understand and identify the genes involved in colorectal cancer. Hereditary nonpolyposis colorectal cancer, or HNPCC, is one condition that causes people to develop colorectal cancer at a young age. The discovery of four genes involved with this disease has provided crucial clues about the role of DNA repair in colorectal and other cancers.',
#  '<question>Who is at risk for Colorectal Cancer? ?<answer>Researchers are working hard to understand and identify the genes involved in colorectal cancer. Hereditary nonpolyposis colorectal cancer, or HNPCC, is one condition that causes people to develop colorectal cancer at a young age. The discovery of four genes involved with this disease has provided crucial clues about the role of DNA repair in colorectal and other cancers.')

# %%
val_df.loc[0,"Question"], val_df.loc[0,"Answer"], val_df.loc[0,"Question-Answer"]
# Out:
# ('Is Langerhans cell histiocytosis inherited ?',
#  'Is Langerhans cell histiocytosis inherited? Although Langerhans cell histiocytosis is generally considered a sporadic, non-hereditary condition, it has reportedly affected more than one individual in a family in a very limited number of cases (particularly identical twins).',
#  '<question>Is Langerhans cell histiocytosis inherited ?<answer>Is Langerhans cell histiocytosis inherited? Although Langerhans cell histiocytosis is generally considered a sporadic, non-hereditary condition, it has reportedly affected more than one individual in a family in a very limited number of cases (particularly identical twins).')

# %% [markdown]
# - **Join the combined text using '\n' into a single string for training and validation separately**

# %%
# YOUR CODE HERE
train_text = '\n'.join(train_df['Question-Answer'].to_list())
val_text = '\n'.join(val_df['Question-Answer'].to_list())

# %% [markdown]
# - **Save the training and validation strings as text files**

# %%
# YOUR CODE HERE
with open('train_text.txt', 'w') as f:
  f.write(train_text)

with open('val_text.txt', 'w') as f:
  f.write(val_text)

# %% [markdown]
# **Exercise 6: Load pre-trained GPT2Tokenizer [0.5 Mark]**
#
# - Use checkpoint = "gpt2"

# %%
# YOUR CODE HERE
checkpoint = "gpt2"
tokenizer = GPT2Tokenizer.from_pretrained(checkpoint)
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]

# %% [markdown]
# **Exercise 7: Tokenize train and validation data and form TextDataset objects [0.5 Mark]**
#
# - Use the loaded pre-trained tokenizer
# - Use training and validation data saved in text files

# %%
# YOUR CODE HERE
train_dataset = TextDataset(tokenizer=tokenizer, file_path="train_text.txt", block_size=128)
val_dataset = TextDataset(tokenizer=tokenizer, file_path="val_text.txt", block_size=128)

# %% [markdown]
# **Exercise 8: Create a DataCollator object [0.5 Mark]**

# %%
# YOUR CODE HERE
data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm=False, return_tensors="pt")

# %% [markdown]
# **Exercise 9: Load pre-trained GPT2LMHeadModel [0.5 Mark]**

# %%
# YOUR CODE HERE
model = GPT2LMHeadModel.from_pretrained(checkpoint)
# Out:
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %% [markdown]
# **Exercise 10: Fine-tune GPT2 Model [1 Mark]**
#
# - Specify training arguments and create a TrainingArguments object (Use 30 epochs)
#
# - Train a GPT-2 model using the provided training arguments
#
# - Save the resulting trained model and tokenizer to a specified output directory

# %%
# Set up the training arguments

# YOUR CODE HERE
model_output_path = "./medical_qna_gpt2_model"

training_args = TrainingArguments(
    output_dir = model_output_path,
    overwrite_output_dir = True,
    per_device_train_batch_size = 2, # try with 2
    per_device_eval_batch_size = 2,  #  try with 2
    num_train_epochs = 30,
    save_steps = 500,
    save_total_limit = 2,
    logging_dir = './logs',
    eval_strategy = 'steps',
    )

# %%
# Train the model
# YOUR CODE HERE
trainer = Trainer(
    model = model,
    args = training_args,
    data_collator = data_collator,
    train_dataset = train_dataset,
    eval_dataset = val_dataset,
)
trainer.train()

# Save the model
# YOUR CODE HERE
trainer.save_model(model_output_path)

# Save the tokenizer
# YOUR CODE HERE
tokenizer.save_pretrained(model_output_path)
# Out:
#     <div>
#
#       <progress value='11650' max='15240' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [11650/15240 32:40 < 10:04, 5.94 it/s, Epoch 22.93/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.198400</td>
#       <td>2.421484</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.866400</td>
#       <td>2.440278</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.602100</td>
#       <td>2.471313</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.392100</td>
#       <td>2.612671</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.188200</td>
#       <td>2.663164</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.032200</td>
#       <td>2.794949</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.905600</td>
#       <td>2.874158</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.817100</td>
#       <td>2.997098</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.723200</td>
#       <td>3.072292</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.627700</td>
#       <td>3.185238</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.562500</td>
#       <td>3.250471</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.490500</td>
#       <td>3.334331</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.445400</td>
#       <td>3.398448</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.391100</td>
#       <td>3.443674</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.355500</td>
#       <td>3.487944</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.320500</td>
#       <td>3.542743</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.290600</td>
#       <td>3.588326</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.269000</td>
#       <td>3.612606</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.245500</td>
#       <td>3.633248</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.223400</td>
#       <td>3.671858</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.210200</td>
#       <td>3.702836</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.193600</td>
#       <td>3.718786</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.183600</td>
#       <td>3.734691</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='15240' max='15240' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [15240/15240 41:20, Epoch 30/30]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>2.198400</td>
#       <td>2.421484</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>1.866400</td>
#       <td>2.440278</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>1.602100</td>
#       <td>2.471313</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>1.392100</td>
#       <td>2.612671</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>1.188200</td>
#       <td>2.663164</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>1.032200</td>
#       <td>2.794949</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.905600</td>
#       <td>2.874158</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.817100</td>
#       <td>2.997098</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.723200</td>
#       <td>3.072292</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.627700</td>
#       <td>3.185238</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.562500</td>
#       <td>3.250471</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.490500</td>
#       <td>3.334331</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.445400</td>
#       <td>3.398448</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.391100</td>
#       <td>3.443674</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.355500</td>
#       <td>3.487944</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.320500</td>
#       <td>3.542743</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.290600</td>
#       <td>3.588326</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.269000</td>
#       <td>3.612606</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.245500</td>
#       <td>3.633248</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.223400</td>
#       <td>3.671858</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.210200</td>
#       <td>3.702836</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.193600</td>
#       <td>3.718786</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.183600</td>
#       <td>3.734691</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.173400</td>
#       <td>3.768023</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.164000</td>
#       <td>3.784629</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.157000</td>
#       <td>3.784861</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.150300</td>
#       <td>3.797043</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.144600</td>
#       <td>3.809142</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.140800</td>
#       <td>3.814339</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.136600</td>
#       <td>3.817753</td>
#     </tr>
#   </tbody>
# </table><p>
# ('./medical_qna_gpt2_model/tokenizer_config.json',
#  './medical_qna_gpt2_model/special_tokens_map.json',
#  './medical_qna_gpt2_model/vocab.json',
#  './medical_qna_gpt2_model/merges.txt',
#  './medical_qna_gpt2_model/added_tokens.json')

# %% [markdown]
# **Exercise 11: Test Model with user input prompts [1 Mark]**
#
# - Create `generate_response()` function that takes a trained *model*, *tokenizer*, and a *prompt* string as input and generates a response using the GPT-2 model
#
# - Test it with some user input prompts

# %%
# YOUR CODE HERE
def generate_response(model, tokenizer, prompt, max_length=100):

    input_ids = tokenizer.encode(prompt, return_tensors="pt")      # 'pt' for returning pytorch tensor

    # Create the attention mask and pad token id
    attention_mask = torch.ones_like(input_ids)
    pad_token_id = tokenizer.eos_token_id

    output = model.generate(
        input_ids,
        max_length=max_length,
        num_return_sequences=1,
        attention_mask=attention_mask,
        pad_token_id=pad_token_id
    )
    response = tokenizer.decode(output[0], skip_special_tokens=True)

    if '<answer>' in response:
        response = response.replace("<answer>", "")
    question, answer = response.split("?", 1)
    return question, answer

# %%
# Load the fine-tuned model and tokenizer

# YOUR CODE HERE
my_model = GPT2LMHeadModel.from_pretrained(model_output_path)
my_tokenizer = GPT2Tokenizer.from_pretrained(model_output_path)

# %%
from pprint import pprint

# %%
# Response from model

# YOUR CODE HERE
prompt = "What precautions to take for a healthy life?"
question, answer = generate_response(my_model, my_tokenizer, prompt)
pprint("Question asked: {}?".format(question))
pprint("Answer: {}".format(answer))
# Out:
# 'Question asked: What precautions to take for a healthy life?'
# ('Answer:  - If you smoke, quit. - Maintain a healthy weight. - Be as '
#  'physically active as you can. - Follow a heart healthy diet. If you smoke, '
#  'quit. Maintain a healthy weight. Be as physically active as you can. Follow '
#  'a heart healthy diet. If you smoke, quit. Smoking can raise your risk for '
#  'coronary heart disease and heart attack. Talk with your doctor about '
#  'programs and products that can help you quit. Also,')

# %%
# Testing with given prompt 1

# YOUR CODE HERE
prompt = "What to do after being diagnosed with cancer?"
question, answer = generate_response(my_model, my_tokenizer, prompt)
pprint("Question asked: {}?".format(question))
pprint("Answer: {}".format(answer))
# Out:
# 'Question asked: What to do after being diagnosed with cancer?'
# ('Answer:  - Meet with a doctor or other healthcare provider who specializes '
#  'in cancer treatment. - Check out books or videos about cancer treatment that '
#  'are available through the NCI website. - Go to educational programs about '
#  'cancer prevention and the prevention of cancer. - Visit the website of the '
#  'National Comprehensive Cancer Network (NCNCNC) and the National Institute on '
#  "Aging's (NIA's) National Comprehensive Cancer Network (NCNCNC). - The NCI "
#  'supports research on cancer')

# %%
# Testing with given prompt 2

# YOUR CODE HERE
prompt = "Symptoms of Depression?"
question, answer = generate_response(my_model, my_tokenizer, prompt)
pprint("Question asked: {}?".format(question))
pprint("Answer: {}".format(answer))
# Out:
# 'Question asked: Symptoms of Depression?'
# ('Answer: Symptoms of depression often vary depending upon the person. Common '
#  'symptoms include - feeling nervous or emotionally empty - tiredness or a '
#  '"slowed down" feeling - feeling guilty or worthless - restlessness and '
#  'irritability - feeling like life is not worth living - sleep problems, '
#  'including trouble getting to sleep, wakefulness in the middle of the night, '
#  'or sleeping too much - eating more or less than usual, usually with '
#  'unplanned weight gain or loss - having persistent')

# %% [markdown]
# **Exercise 12: Compare the performance of a *GPT2 model* with the *GPT2 model fine-tuned* on MedQuAD data [1 Mark]**
#
# - Load another pre-trained GPT2LMHeadModel and do not fine-tune it
#
# - To generate response using the untuned model, pass it as a parameter to `generate_response()` function
#
# - Test both models (fine-tuned and untuned) with below user input prompts:
#
#     - "What precautions to take for a healthy life?"
#     - "What to do after being diagnosed with cancer?"
#     - "What to do when feeling sick?"

# %%
# Load a pre-trained GPT2 model, do not finetune it with MedQuAD data

# YOUR CODE HERE
pretrained_model = GPT2LMHeadModel.from_pretrained(checkpoint)

# %%
# Testing with finetuned model: prompt 1

# YOUR CODE HERE
prompt = "Symptoms of Depression?"
question, answer = generate_response(pretrained_model, my_tokenizer, prompt)
pprint("Question asked: {}?".format(question))
pprint("Answer: {}".format(answer))
# Out:
# 'Question asked: Symptoms of Depression?'
# ('Answer: \n'
#  '\n'
#  'The symptoms of depression are often similar to those of other mental '
#  'illnesses.\n'
#  '\n'
#  'Symptoms of depression are often similar to those of other mental illnesses. '
#  'Depression is a mental illness that is caused by a lack of motivation or '
#  'control.\n'
#  '\n'
#  'A person with depression is often unable to control their emotions, and they '
#  'often feel like they are being controlled.\n'
#  '\n'
#  'A person with depression is often unable to control their emotions, and they '
#  'often feel like they are being controlled')

# %%
# Testing with untuned model: prompt 1

# YOUR CODE HERE
prompt = "Symptoms of Depression?"
question, answer = generate_response(my_model, my_tokenizer, prompt)
pprint("Question asked: {}?".format(question))
pprint("Answer: {}".format(answer))
# Out:
# 'Question asked: Symptoms of Depression?'
# ('Answer: Symptoms of depression often vary depending upon the person. Common '
#  'symptoms include - feeling nervous or emotionally empty - tiredness or a '
#  '"slowed down" feeling - feeling guilty or worthless - restlessness and '
#  'irritability - feeling like life is not worth living - sleep problems, '
#  'including trouble getting to sleep, wakefulness in the middle of the night, '
#  'or sleeping too much - eating more or less than usual, usually with '
#  'unplanned weight gain or loss - having persistent')

# %%
# Testing with finetuned model: prompt 2

# YOUR CODE HERE
prompt = "What precautions to take for a healthy life?"
question, answer = generate_response(pretrained_model, my_tokenizer, prompt)
pprint("Question asked: {}?".format(question))
pprint("Answer: {}".format(answer))
# Out:
# 'Question asked: What precautions to take for a healthy life?'
# ('Answer: \n'
#  '\n'
#  "The following are some of the most common questions you'll hear from your "
#  'doctor or nurse about your health.\n'
#  '\n'
#  'What are the risks of taking a drug that can cause cancer?\n'
#  '\n'
#  'The risks of taking a drug that can cause cancer are very high.\n'
#  '\n'
#  'What are the risks of taking a drug that can cause cancer?\n'
#  '\n'
#  'The risks of taking a drug that can cause cancer are very high.\n'
#  '\n'
#  'What are the risks')

# %%
# Testing with untuned model: prompt 2

# YOUR CODE HERE
prompt = "What precautions to take for a healthy life?"
question, answer = generate_response(my_model, my_tokenizer, prompt)
pprint("Question asked: {}?".format(question))
pprint("Answer: {}".format(answer))
# Out:
# 'Question asked: What precautions to take for a healthy life?'
# ('Answer:  - If you smoke, quit. - Maintain a healthy weight. - Be as '
#  'physically active as you can. - Follow a heart healthy diet. If you smoke, '
#  'quit. Maintain a healthy weight. Be as physically active as you can. Follow '
#  'a heart healthy diet. If you smoke, quit. Smoking can raise your risk for '
#  'coronary heart disease and heart attack. Talk with your doctor about '
#  'programs and products that can help you quit. Also,')

# %%
# Testing with finetuned model: prompt 3

# YOUR CODE HERE
prompt = "What to do after being diagnosed with cancer?"
question, answer = generate_response(pretrained_model, my_tokenizer, prompt)
pprint("Question asked: {}?".format(question))
pprint("Answer: {}".format(answer))
# Out:
# 'Question asked: What to do after being diagnosed with cancer?'
# ('Answer: \n'
#  '\n'
#  "The first step is to get your doctor's approval for a treatment.\n"
#  '\n'
#  'If you have a cancer diagnosis, you may need to get a second opinion.\n'
#  '\n'
#  'If you have a cancer diagnosis, you may need to get a second opinion. If you '
#  'have a cancer diagnosis, you may need to get a third opinion.\n'
#  '\n'
#  'If you have a cancer diagnosis, you may need to get a third opinion. If you '
#  'have a cancer')

# %%
# Testing with untuned model: prompt 3

# YOUR CODE HERE
prompt = "What to do after being diagnosed with cancer?"
question, answer = generate_response(my_model, my_tokenizer, prompt)
pprint("Question asked: {}?".format(question))
pprint("Answer: {}".format(answer))
# Out:
# 'Question asked: What to do after being diagnosed with cancer?'
# ('Answer:  - Meet with a doctor or other healthcare provider who specializes '
#  'in cancer treatment. - Check out books or videos about cancer treatment that '
#  'are available through the NCI website. - Go to educational programs about '
#  'cancer prevention and the prevention of cancer. - Visit the website of the '
#  'National Comprehensive Cancer Network (NCNCNC) and the National Institute on '
#  "Aging's (NIA's) National Comprehensive Cancer Network (NCNCNC). - The NCI "
#  'supports research on cancer')

# %%
train_df[train_df.Focus=='Depression']
# Out:
#           Focus       CUI SemanticType SemanticGroup  \
# 130  Depression  C0349217         T048     Disorders
# 268  Depression  C0349217         T048     Disorders
# 269  Depression  C0349217         T048     Disorders
# 319  Depression  C0349217         T048     Disorders
#
#                                      Question  \
# 130  What are the treatments for Depression ?
# 268     What are the symptoms of Depression ?
# 269     What are the symptoms of Depression ?
# 319                What is (are) Depression ?
#
#                                                 Answer  \
# 130  Several studies are looking at ways to help ol...
# 268  Symptoms of depression often vary depending up...
# 269  Common Symptoms There are many symptoms associ...
# 319  Major depressive disorder, also called major d...
#
#                                        Question-Answer
# 130  <question>What are the treatments for Depressi...
# 268  <question>What are the symptoms of Depression ...
# 269  <question>What are the symptoms of Depression ...
# 319  <question>What is (are) Depression ?<answer>Ma...

# %%
train_df[train_df.Focus.str.contains('Cancer')]
# Out:
#                   Focus       CUI SemanticType SemanticGroup  \
# 0     Colorectal Cancer  C1527249         T191     Disorders
# 17        Breast Cancer  C0006142         T191     Disorders
# 18          Skin Cancer  C0007114         T191     Disorders
# 25          Lung Cancer  C0242379         T191     Disorders
# 27     Surviving Cancer  C0006826         T191     Disorders
# 40          Lung Cancer  C0242379         T191     Disorders
# 56          Skin Cancer  C0007114         T191     Disorders
# 61    Colorectal Cancer  C1527249         T191     Disorders
# 62        Breast Cancer  C0006142         T191     Disorders
# 76      Prostate Cancer  C0376358         T191     Disorders
# 79    Colorectal Cancer  C1527249         T191     Disorders
# 83          Lung Cancer  C0242379         T191     Disorders
# 86          Lung Cancer  C0242379         T191     Disorders
# 89        Breast Cancer  C0006142         T191     Disorders
# 103       Breast Cancer  C0006142         T191     Disorders
# 114   Colorectal Cancer  C1527249         T191     Disorders
# 120     Prostate Cancer  C0376358         T191     Disorders
# 122         Skin Cancer  C0007114         T191     Disorders
# 124    Surviving Cancer  C0006826         T191     Disorders
# 125         Skin Cancer  C0007114         T191     Disorders
# 149  Endometrial Cancer  C1883486         T191     Disorders
# 195     Prostate Cancer  C0376358         T191     Disorders
# 226     Prostate Cancer  C0376358         T191     Disorders
# 264    Surviving Cancer  C0006826         T191     Disorders
# 282    Surviving Cancer  C0006826         T191     Disorders
# 340  Endometrial Cancer  C1883486         T191     Disorders
# 364  Endometrial Cancer  C1883486         T191     Disorders
# 372  Endometrial Cancer  C1883486         T191     Disorders
#
#                                               Question  \
# 0              Who is at risk for Colorectal Cancer? ?
# 17            What are the symptoms of Breast Cancer ?
# 18                         What is (are) Skin Cancer ?
# 25                   Who is at risk for Lung Cancer? ?
# 27         What are the symptoms of Surviving Cancer ?
# 40           What are the treatments for Lung Cancer ?
# 56                   Who is at risk for Skin Cancer? ?
# 61        What are the symptoms of Colorectal Cancer ?
# 62                     How to diagnose Breast Cancer ?
# 76          What are the symptoms of Prostate Cancer ?
# 79             Who is at risk for Colorectal Cancer? ?
# 83                        How to prevent Lung Cancer ?
# 86                         What is (are) Lung Cancer ?
# 89            What are the symptoms of Breast Cancer ?
# 103                      What is (are) Breast Cancer ?
# 114       What are the symptoms of Colorectal Cancer ?
# 120         What are the symptoms of Prostate Cancer ?
# 122                          What causes Skin Cancer ?
# 124                   What is (are) Surviving Cancer ?
# 125                        What is (are) Skin Cancer ?
# 149  what research (or clinical trials) is being do...
# 195                    What is (are) Prostate Cancer ?
# 226         What are the symptoms of Prostate Cancer ?
# 264     What are the treatments for Surviving Cancer ?
# 282     What are the treatments for Surviving Cancer ?
# 340   What are the treatments for Endometrial Cancer ?
# 364                 What is (are) Endometrial Cancer ?
# 372           Who is at risk for Endometrial Cancer? ?
#
#                                                 Answer  \
# 0    Researchers are working hard to understand and...
# 17   Signs of breast cancer include a lump or chang...
# 18   Key Points - Skin cancer is a disease in which...
# 25   Different factors increase or decrease the ris...
# 27   Some signs that may indicate you need professi...
# 40   Researchers continue to look at new ways to co...
# 56   Key Points - Avoiding risk factors and increas...
# 61   Most cancers in their early, most treatable st...
# 62   Tests that examine the breasts are used to det...
# 76   Yes. Any of the symptoms caused by prostate ca...
# 79   Different factors increase or decrease the ris...
# 83   Key Points - Avoiding risk factors and increas...
# 86   The body is made up of many types of cells. No...
# 89   When breast cancer first develops, there may b...
# 103  Breast cancer affects one in eight women durin...
# 114  Possible signs of colorectal cancer include: -...
# 120  - a need to urinate frequently, especially at ...
# 122  Scientists have been able to identify the caus...
# 124  Follow-up cancer care involves regular medical...
# 125  Skin cancer occurs when cancer cells form in t...
# 149  Cancer prevention clinical trials are used to ...
# 195  The prostate is a male sex gland, about the si...
# 226  Symptoms Most cancers in their early, most tre...
# 264  Fatigue, or feeling extremely tired, is a comm...
# 282  Certain kinds of chemotherapy and medicines co...
# 340  Key Points - There are different types of trea...
# 364  Key Points - Endometrial cancer is a disease i...
# 372  Obesity and having metabolic syndrome may incr...
#
#                                        Question-Answer
# 0    <question>Who is at risk for Colorectal Cancer...
# 17   <question>What are the symptoms of Breast Canc...
# 18   <question>What is (are) Skin Cancer ?<answer>K...
# 25   <question>Who is at risk for Lung Cancer? ?<an...
# 27   <question>What are the symptoms of Surviving C...
# 40   <question>What are the treatments for Lung Can...
# 56   <question>Who is at risk for Skin Cancer? ?<an...
# 61   <question>What are the symptoms of Colorectal ...
# 62   <question>How to diagnose Breast Cancer ?<answ...
# 76   <question>What are the symptoms of Prostate Ca...
# 79   <question>Who is at risk for Colorectal Cancer...
# 83   <question>How to prevent Lung Cancer ?<answer>...
# 86   <question>What is (are) Lung Cancer ?<answer>T...
# 89   <question>What are the symptoms of Breast Canc...
# 103  <question>What is (are) Breast Cancer ?<answer...
# 114  <question>What are the symptoms of Colorectal ...
# 120  <question>What are the symptoms of Prostate Ca...
# 122  <question>What causes Skin Cancer ?<answer>Sci...
# 124  <question>What is (are) Surviving Cancer ?<ans...
# 125  <question>What is (are) Skin Cancer ?<answer>S...
# 149  <question>what research (or clinical trials) i...
# 195  <question>What is (are) Prostate Cancer ?<answ...
# 226  <question>What are the symptoms of Prostate Ca...
# 264  <question>What are the treatments for Survivin...
# 282  <question>What are the treatments for Survivin...
# 340  <question>What are the treatments for Endometr...
# 364  <question>What is (are) Endometrial Cancer ?<a...
# 372  <question>Who is at risk for Endometrial Cance...
